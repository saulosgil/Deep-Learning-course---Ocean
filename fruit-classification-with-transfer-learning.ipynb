# %% [markdown]
# This is a simple example using Transfer Learning for an image recognition problem.

# %% [markdown]
# # Imports de Libs

# %%
# General Libs
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
#from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Lendo o dataset

# %%
# Alguns parâmetros para leitura do dataset
im_shape = (299,299)

TRAINING_DIR = '../input/amazon-fruits-small/ds_frutas_am/train'
TEST_DIR = '../input/amazon-fruits-small/ds_frutas_am/test'

seed = 10

BATCH_SIZE = 16

# %%
#Using keras ImageGenerator and flow_from_directoty

# Image dataset without augmentation
#data_generator = ImageDataGenerator(preprocessing_function=preprocess_input, validation_split=0.2)
# With augmentation
data_generator = ImageDataGenerator(
        validation_split=0.2,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        preprocessing_function=preprocess_input,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')
val_data_generator = ImageDataGenerator(preprocessing_function=preprocess_input,validation_split=0.2)

# %%
# Generator para parte train
train_generator = data_generator.flow_from_directory(TRAINING_DIR, target_size=im_shape, shuffle=True, seed=seed,
                                                     class_mode='categorical', batch_size=BATCH_SIZE, subset="training")
# Generator para parte validação
validation_generator = val_data_generator.flow_from_directory(TRAINING_DIR, target_size=im_shape, shuffle=False, seed=seed,
                                                     class_mode='categorical', batch_size=BATCH_SIZE, subset="validation")

# Generator para dataset de teste
test_generator = ImageDataGenerator(preprocessing_function=preprocess_input)
test_generator = test_generator.flow_from_directory(TEST_DIR, target_size=im_shape, shuffle=False, seed=seed,
                                                     class_mode='categorical', batch_size=BATCH_SIZE)

nb_train_samples = train_generator.samples
nb_validation_samples = validation_generator.samples
nb_test_samples = test_generator.samples
classes = list(train_generator.class_indices.keys())
print('Classes: '+str(classes))
num_classes  = len(classes)
# Out:
# Found 72 images belonging to 6 classes.
# Found 18 images belonging to 6 classes.
# Found 30 images belonging to 6 classes.
# Classes: ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']

# %%
# Visualizando alguns exemplos do dataset por meio do Generator criado
plt.figure(figsize=(15,15))
for i in range(9):
    #gera subfigures
    plt.subplot(330 + 1 + i)
    batch = train_generator.next()[0]*255
    image = batch[0].astype('uint8')
    plt.imshow(image)
plt.show()

# %% [markdown]
# # Transfer Learning from a Deep Model

# %%
base_model = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(im_shape[0], im_shape[1], 3))

x = base_model.output
x = Flatten()(x)
x = Dense(100, activation='relu')(x)
predictions = Dense(num_classes, activation='softmax', kernel_initializer='random_uniform')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Freezing pretrained layers
for layer in base_model.layers:
    layer.trainable=False
    
optimizer = Adam()
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 2s 0us/step

# %%
epochs = 80

# Saving the best model
callbacks_list = [
    keras.callbacks.ModelCheckpoint(
        filepath='model.h5',
        monitor='val_loss', save_best_only=True, verbose=1),
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=10,verbose=1)
]

history = model.fit(
        train_generator,
        steps_per_epoch=nb_train_samples // BATCH_SIZE,
        epochs=epochs,
        callbacks = callbacks_list,
        validation_data=validation_generator,
        verbose = 1,
        validation_steps=nb_validation_samples // BATCH_SIZE)
# Out:
# Epoch 1/80
# 4/4 [==============================] - ETA: 0s - loss: 6.4862 - accuracy: 0.1875
# Epoch 00001: val_loss improved from inf to 1.46867, saving model to model.h5
# 4/4 [==============================] - 21s 5s/step - loss: 6.4862 - accuracy: 0.1875 - val_loss: 1.4687 - val_accuracy: 0.6250
# Epoch 2/80
# 4/4 [==============================] - ETA: 0s - loss: 3.5020 - accuracy: 0.5536
# Epoch 00002: val_loss did not improve from 1.46867
# 4/4 [==============================] - 14s 4s/step - loss: 3.5020 - accuracy: 0.5536 - val_loss: 2.3747 - val_accuracy: 0.5625
# Epoch 3/80
# 4/4 [==============================] - ETA: 0s - loss: 2.2247 - accuracy: 0.5179
# Epoch 00003: val_loss did not improve from 1.46867
# 4/4 [==============================] - 16s 4s/step - loss: 2.2247 - accuracy: 0.5179 - val_loss: 1.5230 - val_accuracy: 0.6250
# Epoch 4/80
# 4/4 [==============================] - ETA: 0s - loss: 1.2068 - accuracy: 0.6786
# Epoch 00004: val_loss improved from 1.46867 to 0.79682, saving model to model.h5
# 4/4 [==============================] - 18s 4s/step - loss: 1.2068 - accuracy: 0.6786 - val_loss: 0.7968 - val_accuracy: 0.6250
# Epoch 5/80
# 4/4 [==============================] - ETA: 0s - loss: 0.9118 - accuracy: 0.6429
# Epoch 00005: val_loss improved from 0.79682 to 0.76507, saving model to model.h5
# 4/4 [==============================] - 18s 4s/step - loss: 0.9118 - accuracy: 0.6429 - val_loss: 0.7651 - val_accuracy: 0.6875
# Epoch 6/80
# 4/4 [==============================] - ETA: 0s - loss: 0.6724 - accuracy: 0.7969
# Epoch 00006: val_loss improved from 0.76507 to 0.51112, saving model to model.h5
# 4/4 [==============================] - 17s 4s/step - loss: 0.6724 - accuracy: 0.7969 - val_loss: 0.5111 - val_accuracy: 0.8125
# Epoch 7/80
# 4/4 [==============================] - ETA: 0s - loss: 0.5228 - accuracy: 0.8393
# Epoch 00007: val_loss improved from 0.51112 to 0.45173, saving model to model.h5
# 4/4 [==============================] - 16s 4s/step - loss: 0.5228 - accuracy: 0.8393 - val_loss: 0.4517 - val_accuracy: 0.8125
# Epoch 8/80
# 4/4 [==============================] - ETA: 0s - loss: 0.3916 - accuracy: 0.8750
# Epoch 00008: val_loss did not improve from 0.45173
# 4/4 [==============================] - 16s 4s/step - loss: 0.3916 - accuracy: 0.8750 - val_loss: 0.4594 - val_accuracy: 0.8750
# Epoch 9/80
# 4/4 [==============================] - ETA: 0s - loss: 0.3879 - accuracy: 0.9107
# Epoch 00009: val_loss improved from 0.45173 to 0.44357, saving model to model.h5
# 4/4 [==============================] - 18s 4s/step - loss: 0.3879 - accuracy: 0.9107 - val_loss: 0.4436 - val_accuracy: 0.8750
# Epoch 10/80
# 4/4 [==============================] - ETA: 0s - loss: 0.2146 - accuracy: 0.9643
# Epoch 00010: val_loss improved from 0.44357 to 0.36688, saving model to model.h5
# 4/4 [==============================] - 16s 4s/step - loss: 0.2146 - accuracy: 0.9643 - val_loss: 0.3669 - val_accuracy: 0.8125
# Epoch 11/80
# 4/4 [==============================] - ETA: 0s - loss: 0.1678 - accuracy: 0.9821
# Epoch 00011: val_loss did not improve from 0.36688
# 4/4 [==============================] - 19s 5s/step - loss: 0.1678 - accuracy: 0.9821 - val_loss: 0.4006 - val_accuracy: 0.8750
# Epoch 12/80
# 4/4 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9643
# Epoch 00012: val_loss did not improve from 0.36688
# 4/4 [==============================] - 14s 4s/step - loss: 0.1483 - accuracy: 0.9643 - val_loss: 0.4178 - val_accuracy: 0.8125
# Epoch 13/80
# 4/4 [==============================] - ETA: 0s - loss: 0.1343 - accuracy: 0.9531
# Epoch 00013: val_loss did not improve from 0.36688
# 4/4 [==============================] - 16s 4s/step - loss: 0.1343 - accuracy: 0.9531 - val_loss: 0.3798 - val_accuracy: 0.8750
# Epoch 14/80
# 4/4 [==============================] - ETA: 0s - loss: 0.1220 - accuracy: 0.9688
# Epoch 00014: val_loss did not improve from 0.36688
# 4/4 [==============================] - 16s 4s/step - loss: 0.1220 - accuracy: 0.9688 - val_loss: 0.3896 - val_accuracy: 0.8750
# Epoch 15/80
# 4/4 [==============================] - ETA: 0s - loss: 0.1268 - accuracy: 0.9821
# Epoch 00015: val_loss improved from 0.36688 to 0.34330, saving model to model.h5
# 4/4 [==============================] - 18s 5s/step - loss: 0.1268 - accuracy: 0.9821 - val_loss: 0.3433 - val_accuracy: 0.8750
# Epoch 16/80
# 4/4 [==============================] - ETA: 0s - loss: 0.1330 - accuracy: 0.9464
# Epoch 00016: val_loss did not improve from 0.34330
# 4/4 [==============================] - 14s 3s/step - loss: 0.1330 - accuracy: 0.9464 - val_loss: 0.3586 - val_accuracy: 0.8750
# Epoch 17/80
# 4/4 [==============================] - ETA: 0s - loss: 0.1269 - accuracy: 0.9464
# Epoch 00017: val_loss did not improve from 0.34330
# 4/4 [==============================] - 14s 4s/step - loss: 0.1269 - accuracy: 0.9464 - val_loss: 0.3572 - val_accuracy: 0.8125
# Epoch 18/80
# 4/4 [==============================] - ETA: 0s - loss: 0.1190 - accuracy: 0.9643
# Epoch 00018: val_loss did not improve from 0.34330
# 4/4 [==============================] - 14s 3s/step - loss: 0.1190 - accuracy: 0.9643 - val_loss: 0.3576 - val_accuracy: 0.8750
# Epoch 19/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0647 - accuracy: 0.9688
# Epoch 00019: val_loss did not improve from 0.34330
# 4/4 [==============================] - 16s 4s/step - loss: 0.0647 - accuracy: 0.9688 - val_loss: 0.4715 - val_accuracy: 0.8750
# Epoch 20/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0623 - accuracy: 1.0000
# Epoch 00020: val_loss did not improve from 0.34330
# 4/4 [==============================] - 14s 3s/step - loss: 0.0623 - accuracy: 1.0000 - val_loss: 0.4327 - val_accuracy: 0.8125
# Epoch 21/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9821
# Epoch 00021: val_loss did not improve from 0.34330
# 4/4 [==============================] - 14s 3s/step - loss: 0.0445 - accuracy: 0.9821 - val_loss: 0.3695 - val_accuracy: 0.8125
# Epoch 22/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0593 - accuracy: 0.9821
# Epoch 00022: val_loss improved from 0.34330 to 0.31505, saving model to model.h5
# 4/4 [==============================] - 16s 4s/step - loss: 0.0593 - accuracy: 0.9821 - val_loss: 0.3150 - val_accuracy: 0.8125
# Epoch 23/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0410 - accuracy: 1.0000
# Epoch 00023: val_loss did not improve from 0.31505
# 4/4 [==============================] - 14s 3s/step - loss: 0.0410 - accuracy: 1.0000 - val_loss: 0.3415 - val_accuracy: 0.8125
# Epoch 24/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0374 - accuracy: 1.0000
# Epoch 00024: val_loss did not improve from 0.31505
# 4/4 [==============================] - 16s 4s/step - loss: 0.0374 - accuracy: 1.0000 - val_loss: 0.3680 - val_accuracy: 0.8125
# Epoch 25/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0374 - accuracy: 1.0000
# Epoch 00025: val_loss did not improve from 0.31505
# 4/4 [==============================] - 16s 4s/step - loss: 0.0374 - accuracy: 1.0000 - val_loss: 0.4102 - val_accuracy: 0.8125
# Epoch 26/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0530 - accuracy: 0.9821
# Epoch 00026: val_loss did not improve from 0.31505
# 4/4 [==============================] - 14s 3s/step - loss: 0.0530 - accuracy: 0.9821 - val_loss: 0.4496 - val_accuracy: 0.8750
# Epoch 27/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0524 - accuracy: 0.9821
# Epoch 00027: val_loss did not improve from 0.31505
# 4/4 [==============================] - 16s 4s/step - loss: 0.0524 - accuracy: 0.9821 - val_loss: 0.4908 - val_accuracy: 0.8750
# Epoch 28/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 1.0000
# Epoch 00028: val_loss did not improve from 0.31505
# 4/4 [==============================] - 14s 3s/step - loss: 0.0174 - accuracy: 1.0000 - val_loss: 0.5162 - val_accuracy: 0.8125
# Epoch 29/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0489 - accuracy: 0.9821
# Epoch 00029: val_loss did not improve from 0.31505
# 4/4 [==============================] - 16s 4s/step - loss: 0.0489 - accuracy: 0.9821 - val_loss: 0.3757 - val_accuracy: 0.8750
# Epoch 30/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 1.0000
# Epoch 00030: val_loss improved from 0.31505 to 0.29933, saving model to model.h5
# 4/4 [==============================] - 16s 4s/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.2993 - val_accuracy: 0.8125
# Epoch 31/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 1.0000
# Epoch 00031: val_loss did not improve from 0.29933
# 4/4 [==============================] - 16s 4s/step - loss: 0.0298 - accuracy: 1.0000 - val_loss: 0.3055 - val_accuracy: 0.8750
# Epoch 32/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0306 - accuracy: 1.0000
# Epoch 00032: val_loss did not improve from 0.29933
# 4/4 [==============================] - 14s 4s/step - loss: 0.0306 - accuracy: 1.0000 - val_loss: 0.4688 - val_accuracy: 0.8125
# Epoch 33/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0541 - accuracy: 1.0000
# Epoch 00033: val_loss did not improve from 0.29933
# 4/4 [==============================] - 14s 3s/step - loss: 0.0541 - accuracy: 1.0000 - val_loss: 0.4083 - val_accuracy: 0.8125
# Epoch 34/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0523 - accuracy: 0.9844
# Epoch 00034: val_loss did not improve from 0.29933
# 4/4 [==============================] - 16s 4s/step - loss: 0.0523 - accuracy: 0.9844 - val_loss: 0.4207 - val_accuracy: 0.8125
# Epoch 35/80
# 4/4 [==============================] - ETA: 0s - loss: 0.1285 - accuracy: 0.9643
# Epoch 00035: val_loss did not improve from 0.29933
# 4/4 [==============================] - 14s 3s/step - loss: 0.1285 - accuracy: 0.9643 - val_loss: 0.3421 - val_accuracy: 0.8750
# Epoch 36/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 1.0000
# Epoch 00036: val_loss improved from 0.29933 to 0.24564, saving model to model.h5
# 4/4 [==============================] - 16s 4s/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.2456 - val_accuracy: 0.9375
# Epoch 37/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0311 - accuracy: 0.9821
# Epoch 00037: val_loss did not improve from 0.24564
# 4/4 [==============================] - 14s 4s/step - loss: 0.0311 - accuracy: 0.9821 - val_loss: 0.2471 - val_accuracy: 0.9375
# Epoch 38/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0310 - accuracy: 0.9821
# Epoch 00038: val_loss did not improve from 0.24564
# 4/4 [==============================] - 14s 3s/step - loss: 0.0310 - accuracy: 0.9821 - val_loss: 0.3082 - val_accuracy: 0.8750
# Epoch 39/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0322 - accuracy: 1.0000
# Epoch 00039: val_loss did not improve from 0.24564
# 4/4 [==============================] - 16s 4s/step - loss: 0.0322 - accuracy: 1.0000 - val_loss: 0.3472 - val_accuracy: 0.8750
# Epoch 40/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0415 - accuracy: 1.0000
# Epoch 00040: val_loss did not improve from 0.24564
# 4/4 [==============================] - 16s 4s/step - loss: 0.0415 - accuracy: 1.0000 - val_loss: 0.2510 - val_accuracy: 0.9375
# Epoch 41/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 1.0000
# Epoch 00041: val_loss improved from 0.24564 to 0.20549, saving model to model.h5
# 4/4 [==============================] - 18s 4s/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.2055 - val_accuracy: 0.9375
# Epoch 42/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0389 - accuracy: 1.0000
# Epoch 00042: val_loss did not improve from 0.20549
# 4/4 [==============================] - 14s 4s/step - loss: 0.0389 - accuracy: 1.0000 - val_loss: 0.2195 - val_accuracy: 0.9375
# Epoch 43/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.9821
# Epoch 00043: val_loss did not improve from 0.20549
# 4/4 [==============================] - 19s 5s/step - loss: 0.0260 - accuracy: 0.9821 - val_loss: 0.2410 - val_accuracy: 0.9375
# Epoch 44/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0315 - accuracy: 0.9844
# Epoch 00044: val_loss did not improve from 0.20549
# 4/4 [==============================] - 16s 4s/step - loss: 0.0315 - accuracy: 0.9844 - val_loss: 0.2804 - val_accuracy: 0.8125
# Epoch 45/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 1.0000
# Epoch 00045: val_loss did not improve from 0.20549
# 4/4 [==============================] - 16s 4s/step - loss: 0.0207 - accuracy: 1.0000 - val_loss: 0.3600 - val_accuracy: 0.7500
# Epoch 46/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0424 - accuracy: 0.9821
# Epoch 00046: val_loss did not improve from 0.20549
# 4/4 [==============================] - 14s 3s/step - loss: 0.0424 - accuracy: 0.9821 - val_loss: 0.3020 - val_accuracy: 0.8125
# Epoch 47/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 1.0000
# Epoch 00047: val_loss did not improve from 0.20549
# 4/4 [==============================] - 14s 4s/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.3189 - val_accuracy: 0.8125
# Epoch 48/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 1.0000
# Epoch 00048: val_loss did not improve from 0.20549
# 4/4 [==============================] - 14s 3s/step - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.3333 - val_accuracy: 0.8125
# Epoch 49/80
# 4/4 [==============================] - ETA: 0s - loss: 0.1170 - accuracy: 0.9821
# Epoch 00049: val_loss did not improve from 0.20549
# 4/4 [==============================] - 16s 4s/step - loss: 0.1170 - accuracy: 0.9821 - val_loss: 0.3835 - val_accuracy: 0.8125
# Epoch 50/80
# 4/4 [==============================] - ETA: 0s - loss: 0.1511 - accuracy: 0.9821
# Epoch 00050: val_loss did not improve from 0.20549
# 4/4 [==============================] - 14s 3s/step - loss: 0.1511 - accuracy: 0.9821 - val_loss: 0.4780 - val_accuracy: 0.7500
# Epoch 51/80
# 4/4 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 1.0000
# Epoch 00051: val_loss did not improve from 0.20549
# 4/4 [==============================] - 14s 3s/step - loss: 0.0332 - accuracy: 1.0000 - val_loss: 0.3671 - val_accuracy: 0.8750
# Epoch 00051: early stopping

# %%
#Vamos ver como foi o treino?
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs_x = range(1, len(loss_values) + 1)
plt.figure(figsize=(10,10))
plt.subplot(2,1,1)
plt.plot(epochs_x, loss_values, 'bo', label='Training loss')
plt.plot(epochs_x, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation Loss and Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
#plt.legend()
plt.subplot(2,1,2)
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
plt.plot(epochs_x, acc_values, 'bo', label='Training acc')
plt.plot(epochs_x, val_acc_values, 'b', label='Validation acc')
#plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
# Load the best saved model
model = load_model('model.h5')

# %%
# Using the validation dataset
score = model.evaluate_generator(validation_generator)
print('Val loss:', score[0])
print('Val accuracy:', score[1])
# Out:
# Val loss: 0.21327203512191772
# Val accuracy: 0.9444444179534912

# %%
# Using the test dataset
score = model.evaluate_generator(test_generator)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.3946230709552765
# Test accuracy: 0.800000011920929

# %%
import itertools

#Plot the confusion matrix. Set Normalize = True/False
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Some reports
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

#Confution Matrix and Classification Report
Y_pred = model.predict_generator(test_generator)#, nb_test_samples // BATCH_SIZE, workers=1)
y_pred = np.argmax(Y_pred, axis=1)
target_names = classes

#Confution Matrix
cm = confusion_matrix(test_generator.classes, y_pred)
plot_confusion_matrix(cm, target_names, normalize=False, title='Confusion Matrix')
print('Classification Report')
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#         acai       1.00      0.60      0.75         5
#      cupuacu       1.00      0.60      0.75         5
#     graviola       1.00      1.00      1.00         5
#      guarana       1.00      0.80      0.89         5
#      pupunha       0.83      1.00      0.91         5
#       tucuma       0.44      0.80      0.57         5
#
#     accuracy                           0.80        30
#    macro avg       0.88      0.80      0.81        30
# weighted avg       0.88      0.80      0.81        30
